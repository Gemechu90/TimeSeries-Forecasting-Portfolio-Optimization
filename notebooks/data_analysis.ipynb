# %% [markdown]
# ## Task 1: Financial Data Analysis Script
# This notebook performs comprehensive analysis of financial data for TSLA, BND, and SPY.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

import warnings
warnings.filterwarnings('ignore')

# %%
# Add the parent directory to the system path 
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.data_analysis import *

# %%
# # Set plotting style
# plt.style.use('seaborn')
# sns.set_palette("husl")

# %%
# 1. Data Collection
print("\n1. Data Collection")
print("-" * 40)
    
start_date = '2015-01-01'
end_date = '2024-12-31'
tickers = ['TSLA', 'BND', 'SPY']
# Out:
# 1. Data Collection
# ----------------------------------------

# %%
# Fetch data for all assets
data_dict = {}
for ticker in tickers:
    data_dict[ticker] = fetch_stock_data(ticker, start_date, end_date)
    print(f"Fetched data for {ticker}")
# Out:
# Fetched data for TSLA
# Fetched data for BND
# Fetched data for SPY

# %%
data_dict
# Out:
# {'TSLA':                                  Open        High         Low       Close  \
#  Date
#  2015-01-02 00:00:00-05:00   14.858000   14.883333   14.217333   14.620667
#  2015-01-05 00:00:00-05:00   14.303333   14.433333   13.810667   14.006000
#  2015-01-06 00:00:00-05:00   14.004000   14.280000   13.614000   14.085333
#  2015-01-07 00:00:00-05:00   14.223333   14.318667   13.985333   14.063333
#  2015-01-08 00:00:00-05:00   14.187333   14.253333   14.000667   14.041333
#  ...                               ...         ...         ...         ...
#  2024-12-23 00:00:00-05:00  431.000000  434.510010  415.410004  430.600006
#  2024-12-24 00:00:00-05:00  435.899994  462.779999  435.140015  462.279999
#  2024-12-26 00:00:00-05:00  465.160004  465.329987  451.019989  454.130005
#  2024-12-27 00:00:00-05:00  449.519989  450.000000  426.500000  431.660004
#  2024-12-30 00:00:00-05:00  419.399994  427.000000  415.750000  417.410004
#
#                               Volume  Dividends  Stock Splits
#  Date
#  2015-01-02 00:00:00-05:00  71466000        0.0           0.0
#  2015-01-05 00:00:00-05:00  80527500        0.0           0.0
#  2015-01-06 00:00:00-05:00  93928500        0.0           0.0
#  2015-01-07 00:00:00-05:00  44526000        0.0           0.0
#  2015-01-08 00:00:00-05:00  51637500        0.0           0.0
#  ...                             ...        ...           ...
#  2024-12-23 00:00:00-05:00  72698100        0.0           0.0
#  2024-12-24 00:00:00-05:00  59551800        0.0           0.0
#  2024-12-26 00:00:00-05:00  76366400        0.0           0.0
#  2024-12-27 00:00:00-05:00  82666800        0.0           0.0
#  2024-12-30 00:00:00-05:00  64941000        0.0           0.0
#
#  [2515 rows x 7 columns],
#  'BND':                                 Open       High        Low      Close  \
#  Date
#  2015-01-02 00:00:00-05:00  62.406572  62.603416  62.398999  62.573132
#  2015-01-05 00:00:00-05:00  62.641277  62.777553  62.610993  62.754841
#  2015-01-06 00:00:00-05:00  62.860820  63.125799  62.860820  62.936527
#  2015-01-07 00:00:00-05:00  62.944119  63.050111  62.875984  62.974403
#  2015-01-08 00:00:00-05:00  62.921392  62.921392  62.815401  62.875969
#  ...                              ...        ...        ...        ...
#  2024-12-23 00:00:00-05:00  71.662946  71.742430  71.474182  71.513924
#  2024-12-24 00:00:00-05:00  71.417238  71.616585  71.387336  71.616585
#  2024-12-26 00:00:00-05:00  71.397300  71.686359  71.397300  71.666428
#  2024-12-27 00:00:00-05:00  71.656459  71.696330  71.506945  71.516914
#  2024-12-30 00:00:00-05:00  71.666430  71.845846  71.666430  71.796005
#
#                              Volume  Dividends  Stock Splits  Capital Gains
#  Date
#  2015-01-02 00:00:00-05:00  2218800      0.000           0.0            0.0
#  2015-01-05 00:00:00-05:00  5820100      0.000           0.0            0.0
#  2015-01-06 00:00:00-05:00  3887600      0.000           0.0            0.0
#  2015-01-07 00:00:00-05:00  2433400      0.000           0.0            0.0
#  2015-01-08 00:00:00-05:00  1873400      0.000           0.0            0.0
#  ...                            ...        ...           ...            ...
#  2024-12-23 00:00:00-05:00  7605400      0.000           0.0            0.0
#  2024-12-24 00:00:00-05:00  4185300      0.233           0.0            0.0
#  2024-12-26 00:00:00-05:00  8714400      0.000           0.0            0.0
#  2024-12-27 00:00:00-05:00  9018700      0.000           0.0            0.0
#  2024-12-30 00:00:00-05:00  8054500      0.000           0.0            0.0
#
#  [2515 rows x 8 columns],
#  'SPY':                                  Open        High         Low       Close  \
#  Date
#  2015-01-02 00:00:00-05:00  173.391022  173.811099  171.542672  172.592865
#  2015-01-05 00:00:00-05:00  171.534266  171.702294  169.165038  169.475891
#  2015-01-06 00:00:00-05:00  169.786733  170.316035  167.073039  167.879593
#  2015-01-07 00:00:00-05:00  169.223897  170.316100  168.770219  169.971634
#  2015-01-08 00:00:00-05:00  171.399856  173.206195  171.383062  172.987747
#  ...                               ...         ...         ...         ...
#  2024-12-23 00:00:00-05:00  590.890015  595.299988  587.659973  594.690002
#  2024-12-24 00:00:00-05:00  596.059998  601.340027  595.469971  601.299988
#  2024-12-26 00:00:00-05:00  599.500000  602.479980  598.080017  601.340027
#  2024-12-27 00:00:00-05:00  597.539978  597.780029  590.760010  595.010010
#  2024-12-30 00:00:00-05:00  587.890015  591.739990  584.409973  588.219971
#
#                                Volume  Dividends  Stock Splits  Capital Gains
#  Date
#  2015-01-02 00:00:00-05:00  121465900        0.0           0.0            0.0
#  2015-01-05 00:00:00-05:00  169632600        0.0           0.0            0.0
#  2015-01-06 00:00:00-05:00  209151400        0.0           0.0            0.0
#  2015-01-07 00:00:00-05:00  125346700        0.0           0.0            0.0
#  2015-01-08 00:00:00-05:00  147217800        0.0           0.0            0.0
#  ...                              ...        ...           ...            ...
#  2024-12-23 00:00:00-05:00   57635800        0.0           0.0            0.0
#  2024-12-24 00:00:00-05:00   33160100        0.0           0.0            0.0
#  2024-12-26 00:00:00-05:00   41219100        0.0           0.0            0.0
#  2024-12-27 00:00:00-05:00   64969300        0.0           0.0            0.0
#  2024-12-30 00:00:00-05:00   56578800        0.0           0.0            0.0
#
#  [2515 rows x 8 columns]}

# %%
# 2. Data Cleaning and Preprocessing
print("\n2. Data Cleaning and Preprocessing")
print("-" * 40)
    
cleaned_data = {}
for ticker in tickers:
    cleaned_data[ticker], missing_values = clean_data(data_dict[ticker], ticker)
    print(f"\nProcessed data for {ticker}")
    print("Missing values:")
    print(missing_values)
    print("\nBasic statistics:")
    print(cleaned_data[ticker]['Close'].describe())
# Out:
# 2. Data Cleaning and Preprocessing
# ----------------------------------------
#
# Processed data for TSLA
# Missing values:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
#
# Basic statistics:
# count    2515.000000
# mean      115.564847
# std       114.104456
# min         9.578000
# 25%        17.185000
# 50%        28.502001
# 75%       220.178337
# max       479.859985
# Name: Close, dtype: float64
#
# Processed data for BND
# Missing values:
# Open             0
# High             0
# Low              0
# Close            0
# Volume           0
# Dividends        0
# Stock Splits     0
# Capital Gains    0
# dtype: int64
#
# Basic statistics:
# count    2515.000000
# mean       69.270704
# std         4.806422
# min        61.860878
# 25%        65.540443
# 50%        68.237907
# 75%        72.893208
# max        78.823280
# Name: Close, dtype: float64
#
# Processed data for SPY
# Missing values:
# Open             0
# High             0
# Low              0
# Close            0
# Volume           0
# Dividends        0
# Stock Splits     0
# Capital Gains    0
# dtype: int64
#
# Basic statistics:
# count    2515.000000
# mean      313.849182
# std       115.727256
# min       156.800858
# 25%       214.656853
# 50%       276.349213
# 75%       403.915649
# max       605.771179
# Name: Close, dtype: float64

# %%
# 3. Price Analysis
print("\n3. Price Analysis")
print("-" * 40)
    
for ticker in tickers:
    print(f"\nAnalyzing price trends for {ticker}")
    plot_price_analysis(cleaned_data[ticker], ticker)
    plt.close()  # Close the plot to free memory
# Out:
# 3. Price Analysis
# ----------------------------------------
#
# Analyzing price trends for TSLA
# Analyzing price trends for BND
# Analyzing price trends for SPY

# %%
# Returns Analysis
print("\n4. Returns Analysis")
print("-" * 40)
    
for ticker in tickers:
    print(f"\nAnalyzing returns distribution for {ticker}")
    plot_returns_distribution(cleaned_data[ticker], ticker)
    plt.close()
# Out:
# 4. Returns Analysis
# ----------------------------------------
#
# Analyzing returns distribution for TSLA
# Analyzing returns distribution for BND
# Analyzing returns distribution for SPY

# %%
# Risk Analysis
print("\n5. Risk Analysis")
print("-" * 40)
    
risk_metrics = {}
for ticker in tickers:
    risk_metrics[ticker] = calculate_risk_metrics(cleaned_data[ticker])
    print(f"\nRisk Metrics for {ticker}:")
    for metric, value in risk_metrics[ticker].items():
        print(f"{metric}: {value:.4f}")
        
    print(f"\nPlotting rolling volatility for {ticker}")
    plot_rolling_volatility(cleaned_data[ticker], ticker)
    plt.close()
# Out:
# 5. Risk Analysis
# ----------------------------------------
#
# Risk Metrics for TSLA:
# VaR_95: -0.0514
# VaR_99: -0.0902
# Daily_Volatility: 0.0360
# Annual_Volatility: 0.5716
# Skewness: 0.2746
# Kurtosis: 4.3965
# Sharpe_Ratio: 0.8376
# Max_Drawdown: -0.7363
#
# Plotting rolling volatility for TSLA
# Risk Metrics for BND:
# VaR_95: -0.0048
# VaR_99: -0.0087
# Daily_Volatility: 0.0034
# Annual_Volatility: 0.0545
# Skewness: -0.9543
# Kurtosis: 37.8440
# Sharpe_Ratio: -0.0869
# Max_Drawdown: -0.1858
#
# Plotting rolling volatility for BND
# Risk Metrics for SPY:
# VaR_95: -0.0168
# VaR_99: -0.0320
# Daily_Volatility: 0.0111
# Annual_Volatility: 0.1762
# Skewness: -0.5550
# Kurtosis: 12.7494
# Sharpe_Ratio: 0.6726
# Max_Drawdown: -0.3372
#
# Plotting rolling volatility for SPY

# %%
# Seasonality Analysis
print("\n Seasonality Analysis")
print("-" * 40)
    
print("\nPerforming seasonality analysis for Tesla")
decomposition = perform_seasonality_analysis(cleaned_data['TSLA'], 'TSLA')
plt.close()
# Out:
#  Seasonality Analysis
# ----------------------------------------
#
# Performing seasonality analysis for Tesla

# %%
# Correlation Analysis
print("\n7. Correlation Analysis")
print("-" * 40)
    
correlation_matrix = analyze_correlations(cleaned_data)
print("\nCorrelation Matrix:")
print(correlation_matrix)
plt.close()
# Out:
# 7. Correlation Analysis
# ----------------------------------------
# Correlation Matrix:
#           TSLA       BND       SPY
# TSLA  1.000000  0.055989  0.465860
# BND   0.055989  1.000000  0.108253
# SPY   0.465860  0.108253  1.000000

# %%
# # 8. Save Processed Data
# print("\n8. Saving Processed Data")
# print("-" * 40)
    
# for ticker, df in cleaned_data.items():
#     df.to_csv(f'{ticker}_processed.csv')
#     print(f"Saved processed data for {ticker}")


# Save Processed Data
print("\n8. Saving Processed Data")
print("-" * 40)

output_folder = "../data/processed/"
for ticker, df in cleaned_data.items():
    df.to_csv(f'{output_folder}{ticker}_processed.csv', index=False)
    print(f"Saved processed data for {ticker} in {output_folder}")
# Out:
# 8. Saving Processed Data
# ----------------------------------------
# Saved processed data for TSLA in ../data/processed/
# Saved processed data for BND in ../data/processed/
# Saved processed data for SPY in ../data/processed/

# %%
# 9. Generate Summary Report
print("\n9. Summary of Findings")
print("-" * 40)
    
generate_summary_report(cleaned_data, risk_metrics, correlation_matrix)
# Out:
# 9. Summary of Findings
# ----------------------------------------
#
# Analysis Summary:
# ----------------------------------------
# Price Analysis:
# - TSLA: Current Price: $417.41, Total Return: 2754.93%
# - BND: Current Price: $71.80, Total Return: 14.74%
# - SPY: Current Price: $588.22, Total Return: 240.81%
#
# Risk Analysis:
# - TSLA:
#   * Annual Volatility: 57.16%
#   * Sharpe Ratio: 0.84
#   * Maximum Drawdown: -73.63%
# - BND:
#   * Annual Volatility: 5.45%
#   * Sharpe Ratio: -0.09
#   * Maximum Drawdown: -18.58%
# - SPY:
#   * Annual Volatility: 17.62%
#   * Sharpe Ratio: 0.67
#   * Maximum Drawdown: -33.72%
#
# Correlation Analysis:

# %%
df_TSLA=pd.read_csv('../data/processed/TSLA_processed.csv')
df_SPY=pd.read_csv('../data/processed/SPY_processed.csv')
df_BND=pd.read_csv('../data/processed/BND_processed.csv')

# %%
df_TSLA
# Out:
#             Open        High         Low       Close    Volume  Dividends  \
# 0      14.858000   14.883333   14.217333   14.620667  71466000        0.0
# 1      14.303333   14.433333   13.810667   14.006000  80527500        0.0
# 2      14.004000   14.280000   13.614000   14.085333  93928500        0.0
# 3      14.223333   14.318667   13.985333   14.063333  44526000        0.0
# 4      14.187333   14.253333   14.000667   14.041333  51637500        0.0
# ...          ...         ...         ...         ...       ...        ...
# 2510  431.000000  434.510010  415.410004  430.600006  72698100        0.0
# 2511  435.899994  462.779999  435.140015  462.279999  59551800        0.0
# 2512  465.160004  465.329987  451.019989  454.130005  76366400        0.0
# 2513  449.519989  450.000000  426.500000  431.660004  82666800        0.0
# 2514  419.399994  427.000000  415.750000  417.410004  64941000        0.0
#
#       Stock Splits  Daily_Return        MA20      MA50      MA200  Volatility
# 0              0.0           NaN         NaN       NaN        NaN         NaN
# 1              0.0     -0.042041         NaN       NaN        NaN         NaN
# 2              0.0      0.005664         NaN       NaN        NaN         NaN
# 3              0.0     -0.001562         NaN       NaN        NaN         NaN
# 4              0.0     -0.001564         NaN       NaN        NaN         NaN
# ...            ...           ...         ...       ...        ...         ...
# 2510           0.0      0.022657  396.037001  324.8296  232.24500    0.595966
# 2511           0.0      0.073572  402.221501  329.6920  233.66755    0.604523
# 2512           0.0     -0.017630  408.016501  334.3832  235.05050    0.613655
# 2513           0.0     -0.049479  412.955000  338.5898  236.36140    0.647214
# 2514           0.0     -0.033012  416.567500  342.5202  237.63595    0.661656
#
# [2515 rows x 12 columns]

# %%
df_SPY
# Out:
#             Open        High         Low       Close     Volume  Dividends  \
# 0     173.391022  173.811099  171.542672  172.592865  121465900        0.0
# 1     171.534266  171.702294  169.165038  169.475891  169632600        0.0
# 2     169.786733  170.316035  167.073039  167.879593  209151400        0.0
# 3     169.223897  170.316100  168.770219  169.971634  125346700        0.0
# 4     171.399856  173.206195  171.383062  172.987747  147217800        0.0
# ...          ...         ...         ...         ...        ...        ...
# 2510  590.890015  595.299988  587.659973  594.690002   57635800        0.0
# 2511  596.059998  601.340027  595.469971  601.299988   33160100        0.0
# 2512  599.500000  602.479980  598.080017  601.340027   41219100        0.0
# 2513  597.539978  597.780029  590.760010  595.010010   64969300        0.0
# 2514  587.890015  591.739990  584.409973  588.219971   56578800        0.0
#
#       Stock Splits  Capital Gains  Daily_Return        MA20        MA50  \
# 0              0.0            0.0           NaN         NaN         NaN
# 1              0.0            0.0     -0.018060         NaN         NaN
# 2              0.0            0.0     -0.009419         NaN         NaN
# 3              0.0            0.0      0.012462         NaN         NaN
# 4              0.0            0.0      0.017745         NaN         NaN
# ...            ...            ...           ...         ...         ...
# 2510           0.0            0.0      0.005988  599.283066  589.740753
# 2511           0.0            0.0      0.011115  599.571780  590.119553
# 2512           0.0            0.0      0.000067  599.707022  590.589650
# 2513           0.0            0.0     -0.010527  599.616458  590.882915
# 2514           0.0            0.0     -0.011412  599.001016  591.039384
#
#            MA200  Volatility
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# ...          ...         ...
# 2510  548.162494    0.134339
# 2511  548.644970    0.139521
# 2512  549.100495    0.138412
# 2513  549.528368    0.143250
# 2514  549.927327    0.146551
#
# [2515 rows x 13 columns]

# %%
df_BND
# Out:
#            Open       High        Low      Close   Volume  Dividends  \
# 0     62.406572  62.603416  62.398999  62.573132  2218800      0.000
# 1     62.641277  62.777553  62.610993  62.754841  5820100      0.000
# 2     62.860820  63.125799  62.860820  62.936527  3887600      0.000
# 3     62.944119  63.050111  62.875984  62.974403  2433400      0.000
# 4     62.921392  62.921392  62.815401  62.875969  1873400      0.000
# ...         ...        ...        ...        ...      ...        ...
# 2510  71.662946  71.742430  71.474182  71.513924  7605400      0.000
# 2511  71.417238  71.616585  71.387336  71.616585  4185300      0.233
# 2512  71.397300  71.686359  71.397300  71.666428  8714400      0.000
# 2513  71.656459  71.696330  71.506945  71.516914  9018700      0.000
# 2514  71.666430  71.845846  71.666430  71.796005  8054500      0.000
#
#       Stock Splits  Capital Gains  Daily_Return       MA20       MA50  \
# 0              0.0            0.0           NaN        NaN        NaN
# 1              0.0            0.0      0.002904        NaN        NaN
# 2              0.0            0.0      0.002895        NaN        NaN
# 3              0.0            0.0      0.000602        NaN        NaN
# 4              0.0            0.0     -0.001563        NaN        NaN
# ...            ...            ...           ...        ...        ...
# 2510           0.0            0.0     -0.003185  72.501550  72.341392
# 2511           0.0            0.0      0.001436  72.454124  72.316880
# 2512           0.0            0.0      0.000696  72.415629  72.287637
# 2513           0.0            0.0     -0.002086  72.359753  72.253429
# 2514           0.0            0.0      0.003902  72.304459  72.231913
#
#           MA200  Volatility
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ...         ...         ...
# 2510  71.462779    0.059713
# 2511  71.468829    0.048666
# 2512  71.476193    0.048701
# 2513  71.483389    0.047404
# 2514  71.494058    0.047684
#
# [2515 rows x 13 columns]
